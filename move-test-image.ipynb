# %%
import shutil
import os

f = open(r'val.txt')
h = open(r'test.txt')


# x=0
# for line in f:
#     text = line.replace("\n", "").split(' ')
#     print(int(text[1]))
#     print(line)
# print(line)

# for line in h:
#     shutil.move(line.split(' ')[0],'test/') ##val or test
#     print(line.split(' ')[0])

# for line in f:
#     shutil.move(line.split(' ')[0],'val/') ##val or test
#     print(line.split(' ')[0])


for line in f:
    print(line.split('/')[1])
    os.makedirs('valdir/'+line.split('/')[1],exist_ok=True)
    shutil.move(line.split(' ')[0],'valdir/'+line.split('/')[1])
    print(line.split(' ')[0])
    
for line in h:
    print(line.split('/')[1])
    os.makedirs('testdir/'+line.split('/')[1],exist_ok=True)
    shutil.move(line.split(' ')[0],'testdir/'+line.split('/')[1])
    print(line.split(' ')[0])
# Out:
# n02111277
# images/n02111277/n02111277_9695.JPEG
# n02111277
# images/n02111277/n02111277_9747.JPEG
# n02111277
# images/n02111277/n02111277_975.JPEG
# n02111277
# images/n02111277/n02111277_9795.JPEG
# n02111277
# images/n02111277/n02111277_980.JPEG
# n02111277
# images/n02111277/n02111277_9800.JPEG
# n02111277
# images/n02111277/n02111277_9886.JPEG
# n02111277
# images/n02111277/n02111277_9942.JPEG
# n02111277
# images/n02111277/n02111277_9947.JPEG
# n02111500
# images/n02111500/n02111500_959.JPEG
# n02111500
# images/n02111500/n02111500_9590.JPEG
# n02111500
# images/n02111500/n02111500_969.JPEG
# n02111500
# images/n02111500/n02111500_975.JPEG
# n02111500
# images/n02111500/n02111500_977.JPEG
# n02111500
# images/n02111500/n02111500_979.JPEG
# n02111500
# images/n02111500/n02111500_98.JPEG
# n02111500
# images/n02111500/n02111500_983.JPEG
# n02111500
# images/n02111500/n02111500_986.JPEG
# n02111889
# images/n02111889/n02111889_9846.JPEG
# n02111889
# ...

# %%
add = os.listdir('valdir')
print(add)
# Out:
# ['n02111277', 'n02111500', 'n02111889', 'n02112018', 'n02112137', 'n02112350', 'n02112706', 'n02113023', 'n02113186', 'n02113624', 'n02113712', 'n02113799', 'n02113978', 'n02114367', 'n02114548', 'n02114712', 'n02114855', 'n02115641', 'n02115913', 'n02116738', 'n02117135', 'n02119022', 'n02119789', 'n02120079', 'n02120505', 'n02123045', 'n02123159', 'n02123394', 'n02123597', 'n02124075', 'n02125311', 'n02127052', 'n02128385', 'n02128757', 'n02128925', 'n02129165', 'n02129604', 'n02130308', 'n02132136', 'n02133161', 'n02134084', 'n02134418', 'n02137549', 'n02138441', 'n02165105', 'n02165456', 'n02167151', 'n02168699', 'n02169497', 'n02172182']
